# %%
from ultralytics import YOLO

model = YOLO(r"ultralytics\cfg\models\26\detect.yaml")
# Out:
# WARNING no model scale passed. Assuming scale='n'.
# C3k2_m
# C3k2_m
# C3k2_m
# C3k2_m

# %% [markdown]
# 要看 yolo5 10 11 26
